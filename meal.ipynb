# %%
import os
os.getcwd()
# Out:
# '/home/nishtha/meal_behaviour'

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_sas('DR1IFF_I.xpt')
data
# Out:
#            SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 0       83732.0  92670.699919  6.994593e+04       1.0       1.0      71.0
# 1       83732.0  92670.699919  6.994593e+04       2.0       1.0      71.0
# 2       83732.0  92670.699919  6.994593e+04       3.0       1.0      71.0
# 3       83732.0  92670.699919  6.994593e+04       4.0       1.0      71.0
# 4       83732.0  92670.699919  6.994593e+04       5.0       1.0      71.0
# 5       83732.0  92670.699919  6.994593e+04       6.0       1.0      71.0
# 6       83732.0  92670.699919  6.994593e+04       7.0       1.0      71.0
# 7       83732.0  92670.699919  6.994593e+04       8.0       1.0      71.0
# 8       83732.0  92670.699919  6.994593e+04       9.0       1.0      71.0
# 9       83732.0  92670.699919  6.994593e+04      10.0       1.0      71.0
# 10      83732.0  92670.699919  6.994593e+04      11.0       1.0      71.0
# 11      83732.0  92670.699919  6.994593e+04      12.0       1.0      71.0
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
mealdata = data.to_csv("/home/nishtha/meal_behaviour/meal.csv")

# %%
meal = pd.read_csv('meal.csv', delimiter=',')

# %%
meal
# Out:
#         Unnamed: 0     SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  \
# 0                0  83732.0  92670.699919  6.994593e+04       1.0       1.0
# 1                1  83732.0  92670.699919  6.994593e+04       2.0       1.0
# 2                2  83732.0  92670.699919  6.994593e+04       3.0       1.0
# 3                3  83732.0  92670.699919  6.994593e+04       4.0       1.0
# 4                4  83732.0  92670.699919  6.994593e+04       5.0       1.0
# 5                5  83732.0  92670.699919  6.994593e+04       6.0       1.0
# 6                6  83732.0  92670.699919  6.994593e+04       7.0       1.0
# 7                7  83732.0  92670.699919  6.994593e+04       8.0       1.0
# 8                8  83732.0  92670.699919  6.994593e+04       9.0       1.0
# 9                9  83732.0  92670.699919  6.994593e+04      10.0       1.0
# 10              10  83732.0  92670.699919  6.994593e+04      11.0       1.0
# ...

# %%
data.head()
# Out:
#       SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  DRABF  \
# 0  83732.0  92670.699919  69945.934107       1.0       1.0      71.0    2.0
# 1  83732.0  92670.699919  69945.934107       2.0       1.0      71.0    2.0
# 2  83732.0  92670.699919  69945.934107       3.0       1.0      71.0    2.0
# 3  83732.0  92670.699919  69945.934107       4.0       1.0      71.0    2.0
# 4  83732.0  92670.699919  69945.934107       5.0       1.0      71.0    2.0
#
#    DRDINT  DR1DBIH  DR1DAY      ...           DR1IM181      DR1IM201  \
# 0     2.0     -1.0     1.0      ...       5.397605e-79  5.397605e-79
# 1     2.0     -1.0     1.0      ...       5.397605e-79  5.397605e-79
# 2     2.0     -1.0     1.0      ...       3.830000e-01  1.000000e-03
# 3     2.0     -1.0     1.0      ...       5.397605e-79  5.397605e-79
# 4     2.0     -1.0     1.0      ...       5.660000e-01  4.000000e-03
#
#        DR1IM221      DR1IP182      DR1IP183      DR1IP184      DR1IP204  \
# ...

# %%
data.tail()
# Out:
#            SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 121476  93702.0  67560.380806  55166.938286       9.0       1.0      49.0
# 121477  93702.0  67560.380806  55166.938286      10.0       1.0      49.0
# 121478  93702.0  67560.380806  55166.938286      11.0       1.0      49.0
# 121479  93702.0  67560.380806  55166.938286      12.0       1.0      49.0
# 121480  93702.0  67560.380806  55166.938286      13.0       1.0      49.0
#
#         DRABF  DRDINT  DR1DBIH  DR1DAY      ...           DR1IM181  \
# 121476    2.0     2.0      1.0     7.0      ...       3.519000e+00
# 121477    2.0     2.0      1.0     7.0      ...       1.020000e-01
# 121478    2.0     2.0      1.0     7.0      ...       5.397605e-79
# 121479    2.0     2.0      1.0     7.0      ...       1.120000e-01
# 121480    2.0     2.0      1.0     7.0      ...       9.640000e-01
#
#             DR1IM201      DR1IM221      DR1IP182      DR1IP183      DR1IP184  \
# ...

# %%
data.sample(5)
# Out:
#            SEQN         WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 21603   85541.0    6629.630675   5335.864346      17.0       1.0      75.0
# 107189  92558.0   57906.178457  48351.538104       3.0       1.0      22.0
# 67972   89370.0  104512.891088  78884.175902       4.0       1.0      75.0
# 8604    84457.0   34053.229081  28448.433957      10.0       1.0      91.0
# 6986    84322.0   16337.528959  13084.531958       1.0       1.0      61.0
#
#         DRABF  DRDINT  DR1DBIH  DR1DAY      ...           DR1IM181  \
# 21603     2.0     2.0      5.0     1.0      ...       1.276000e+00
# 107189    2.0     2.0      1.0     1.0      ...       5.397605e-79
# 67972     2.0     2.0      5.0     1.0      ...       7.020000e-01
# 8604      2.0     2.0      3.0     7.0      ...       2.375000e+00
# 6986      2.0     2.0     23.0     7.0      ...       4.206000e+00
#
#             DR1IM201      DR1IM221      DR1IP182      DR1IP183      DR1IP184  \
# ...

# %%
data.shape
# Out:
# (121481, 84)

# %%
data['SEQN']
# Out:
# 0         83732.0
# 1         83732.0
# 2         83732.0
# 3         83732.0
# 4         83732.0
# 5         83732.0
# 6         83732.0
# 7         83732.0
# 8         83732.0
# 9         83732.0
# 10        83732.0
# 11        83732.0
# 12        83732.0
# 13        83732.0
# 14        83732.0
# 15        83732.0
# 16        83732.0
# 17        83733.0
# 18        83733.0
# 19        83733.0
# 20        83733.0
# 21        83733.0
# 22        83733.0
# 23        83733.0
# 24        83733.0
# 25        83734.0
# 26        83734.0
# 27        83734.0
# 28        83734.0
# 29        83734.0
#            ...
# 121451    93701.0
# 121452    93701.0
# 121453    93701.0
# 121454    93701.0
# 121455    93701.0
# 121456    93701.0
# 121457    93701.0
# 121458    93701.0
# 121459    93701.0
# 121460    93701.0
# 121461    93701.0
# 121462    93701.0
# 121463    93701.0
# 121464    93701.0
# 121465    93701.0
# 121466    93701.0
# 121467    93701.0
# 121468    93702.0
# 121469    93702.0
# ...

# %%
data = data.dropna()

# %%
X = data[['SEQN', 'DR1ILINE', 'DR1_020', 'DR1_030Z']].copy()

# %%
X
# Out:
#            SEQN  DR1ILINE  DR1_020  DR1_030Z
# 0       83732.0       1.0  27000.0       1.0
# 1       83732.0       2.0  27000.0       1.0
# 2       83732.0       3.0  27000.0       1.0
# 3       83732.0       4.0  28800.0       7.0
# 4       83732.0       5.0  32400.0       1.0
# 5       83732.0       6.0  32400.0       1.0
# 6       83732.0       7.0  41400.0       6.0
# 7       83732.0       8.0  45000.0       2.0
# 8       83732.0       9.0  45000.0       2.0
# 9       83732.0      10.0  45000.0       2.0
# 10      83732.0      11.0  45000.0       2.0
# 11      83732.0      12.0  64800.0       4.0
# 12      83732.0      13.0  64800.0       4.0
# 13      83732.0      14.0  64800.0       4.0
# 14      83732.0      15.0  64800.0       4.0
# 16      83732.0      17.0  75600.0       6.0
# 17      83733.0       1.0  37800.0       3.0
# 18      83733.0       2.0  37800.0       3.0
# 19      83733.0       3.0  46800.0       9.0
# 20      83733.0       4.0  72000.0       3.0
# ...

# %%
Y = data[['DR1ICARB']].copy()
Y
# Out:
#             DR1ICARB
# 0       5.397605e-79
# 1       3.560000e+00
# 2       2.320000e+00
# 3       5.397605e-79
# 4       4.088000e+01
# 5       2.500000e-01
# 6       1.740000e+00
# 7       4.867000e+01
# 8       1.170000e+00
# 9       2.740000e+00
# 10      5.397605e-79
# 11      1.330000e+00
# 12      8.460000e+00
# 13      5.397605e-79
# 14      5.961000e+01
# 16      2.256000e+01
# 17      5.397605e-79
# 18      8.330000e+00
# 19      4.723000e+01
# 20      1.047000e+01
# 21      2.821000e+01
# 22      2.549000e+02
# 23      5.397605e-79
# 24      7.710000e+00
# 25      7.200000e-01
# 26      9.900000e-01
# 27      5.397605e-79
# 28      6.970000e+00
# 29      2.612000e+01
# 30      1.600000e-01
# ...              ...
# 121448  3.700000e-01
# 121449  1.387400e+02
# 121450  5.397605e-79
# 121451  2.606000e+01
# 121452  3.900000e-01
# 121453  6.100000e-01
# 121454  6.017000e+01
# 121456  1.320000e+01
# 121457  2.598000e+01
# 121458  5.276000e+01
# 121459  5.397605e-79
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(X['DR1_020'][:500])
#print(small_data['DR1_020'][:500])

# %%
X.dtypes
# Out:
# SEQN        float64
# DR1ILINE    float64
# DR1_020     float64
# DR1_030Z    float64
# dtype: object

# %%
Y.dtypes
# Out:
# DR1ICARB    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,random_state=0)

# %%
X_train.shape
# Out:
# (82643, 4)

# %%
X_test.shape
# Out:
# (27548, 4)

# %%
y_train.shape
# Out:
# (82643, 1)

# %%
y_test.shape
# Out:
# (27548, 1)

# %%
82643+27548
# Out:
# 110191

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train,y_train)

# %%
lr
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[-4.58475979e-05 -7.66565387e-01  2.56654868e-04 -6.04828110e-02]]
# [15.42017604]

# %%
help(lr)
# Out:
# Help on LinearRegression in module sklearn.linear_model.base object:
#
# class LinearRegression(LinearModel, sklearn.base.RegressorMixin)
#  |  LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : boolean, optional, default True
#  |      whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (e.g. data is expected to be already centered).
#  |
#  |  normalize : boolean, optional, default False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
#  |      If True, the regressors X will be normalized before regression by
#  |      subtracting the mean and dividing by the l2-norm.
#  |      If you wish to standardize, please use
#  |      :class:`sklearn.preprocessing.StandardScaler` before calling ``fit`` on
# ...

# %%
lr.score(X_train, y_train)*100
# Out:
# 2.1297397337820656

# %%
lr.score(X_test, y_test)
# Out:
# 0.024443947391377785

# %%
plt.semilogy(X['DR1_020'])

# %%
plt.plot(X['DR1_020'])

# %%
plt.semilogx(X['DR1_020'])

# %%
plt.loglog(X['DR1_020'])

# %%
X['DR1_020']
# Out:
# 0         27000.0
# 1         27000.0
# 2         27000.0
# 3         28800.0
# 4         32400.0
# 5         32400.0
# 6         41400.0
# 7         45000.0
# 8         45000.0
# 9         45000.0
# 10        45000.0
# 11        64800.0
# 12        64800.0
# 13        64800.0
# 14        64800.0
# 16        75600.0
# 17        37800.0
# 18        37800.0
# 19        46800.0
# 20        72000.0
# 21        72000.0
# 22        72000.0
# 23        72000.0
# 24        72000.0
# 25        32400.0
# 26        32400.0
# 27        32400.0
# 28        32400.0
# 29        32400.0
# 30        32400.0
#            ...
# 121448    67500.0
# 121449    67500.0
# 121450    67500.0
# 121451    31200.0
# 121452    31200.0
# 121453    31200.0
# 121454    31200.0
# 121456    42600.0
# 121457    42600.0
# 121458    42600.0
# 121459    42600.0
# 121460    42600.0
# 121461    51300.0
# 121462    52200.0
# 121463    57600.0
# 121464    68400.0
# 121465    68400.0
# 121466    68400.0
# 121469    32400.0
# ...

# %%
X
# Out:
#            SEQN  DR1ILINE  DR1_020  DR1_030Z
# 0       83732.0       1.0  27000.0       1.0
# 1       83732.0       2.0  27000.0       1.0
# 2       83732.0       3.0  27000.0       1.0
# 3       83732.0       4.0  28800.0       7.0
# 4       83732.0       5.0  32400.0       1.0
# 5       83732.0       6.0  32400.0       1.0
# 6       83732.0       7.0  41400.0       6.0
# 7       83732.0       8.0  45000.0       2.0
# 8       83732.0       9.0  45000.0       2.0
# 9       83732.0      10.0  45000.0       2.0
# 10      83732.0      11.0  45000.0       2.0
# 11      83732.0      12.0  64800.0       4.0
# 12      83732.0      13.0  64800.0       4.0
# 13      83732.0      14.0  64800.0       4.0
# 14      83732.0      15.0  64800.0       4.0
# 16      83732.0      17.0  75600.0       6.0
# 17      83733.0       1.0  37800.0       3.0
# 18      83733.0       2.0  37800.0       3.0
# 19      83733.0       3.0  46800.0       9.0
# 20      83733.0       4.0  72000.0       3.0
# ...

# %%
#plt.plot(X_train['DR1_020'])

# %%
X['DR1_020'].plot()

# %%
plt.semilogx(X['DR1_020'])

# %%
X['DR1_020']
# Out:
# 0         27000.0
# 1         27000.0
# 2         27000.0
# 3         28800.0
# 4         32400.0
# 5         32400.0
# 6         41400.0
# 7         45000.0
# 8         45000.0
# 9         45000.0
# 10        45000.0
# 11        64800.0
# 12        64800.0
# 13        64800.0
# 14        64800.0
# 16        75600.0
# 17        37800.0
# 18        37800.0
# 19        46800.0
# 20        72000.0
# 21        72000.0
# 22        72000.0
# 23        72000.0
# 24        72000.0
# 25        32400.0
# 26        32400.0
# 27        32400.0
# 28        32400.0
# 29        32400.0
# 30        32400.0
#            ...
# 121448    67500.0
# 121449    67500.0
# 121450    67500.0
# 121451    31200.0
# 121452    31200.0
# 121453    31200.0
# 121454    31200.0
# 121456    42600.0
# 121457    42600.0
# 121458    42600.0
# 121459    42600.0
# 121460    42600.0
# 121461    51300.0
# 121462    52200.0
# 121463    57600.0
# 121464    68400.0
# 121465    68400.0
# 121466    68400.0
# 121469    32400.0
# ...

# %%
X
# Out:
#            SEQN  DR1ILINE  DR1_020  DR1_030Z
# 0       83732.0       1.0  27000.0       1.0
# 1       83732.0       2.0  27000.0       1.0
# 2       83732.0       3.0  27000.0       1.0
# 3       83732.0       4.0  28800.0       7.0
# 4       83732.0       5.0  32400.0       1.0
# 5       83732.0       6.0  32400.0       1.0
# 6       83732.0       7.0  41400.0       6.0
# 7       83732.0       8.0  45000.0       2.0
# 8       83732.0       9.0  45000.0       2.0
# 9       83732.0      10.0  45000.0       2.0
# 10      83732.0      11.0  45000.0       2.0
# 11      83732.0      12.0  64800.0       4.0
# 12      83732.0      13.0  64800.0       4.0
# 13      83732.0      14.0  64800.0       4.0
# 14      83732.0      15.0  64800.0       4.0
# 16      83732.0      17.0  75600.0       6.0
# 17      83733.0       1.0  37800.0       3.0
# 18      83733.0       2.0  37800.0       3.0
# 19      83733.0       3.0  46800.0       9.0
# 20      83733.0       4.0  72000.0       3.0
# ...

# %%
time = []
for a, b in X.iterrows():
    if b['SEQN'] == 83732.0:
        time.append(b['DR1_020'])

# %%
next(X.iterrows())
# Out:
# (0, SEQN        83732.0
#  DR1ILINE        1.0
#  DR1_020     27000.0
#  DR1_030Z        1.0
#  Name: 0, dtype: float64)

# %%
time
# Out:
# [27000.0,
#  27000.0,
#  27000.0,
#  28800.0,
#  32400.0,
#  32400.0,
#  41400.0,
#  45000.0,
#  45000.0,
#  45000.0,
#  45000.0,
#  64800.0,
#  64800.0,
#  64800.0,
#  64800.0,
#  75600.0]

# %%
plt.plot(time)

# %%
len(time)
# Out:
# 16

# %%
Y
# Out:
#             DR1ICARB
# 0       5.397605e-79
# 1       3.560000e+00
# 2       2.320000e+00
# 3       5.397605e-79
# 4       4.088000e+01
# 5       2.500000e-01
# 6       1.740000e+00
# 7       4.867000e+01
# 8       1.170000e+00
# 9       2.740000e+00
# 10      5.397605e-79
# 11      1.330000e+00
# 12      8.460000e+00
# 13      5.397605e-79
# 14      5.961000e+01
# 16      2.256000e+01
# 17      5.397605e-79
# 18      8.330000e+00
# 19      4.723000e+01
# 20      1.047000e+01
# 21      2.821000e+01
# 22      2.549000e+02
# 23      5.397605e-79
# 24      7.710000e+00
# 25      7.200000e-01
# 26      9.900000e-01
# 27      5.397605e-79
# 28      6.970000e+00
# 29      2.612000e+01
# 30      1.600000e-01
# ...              ...
# 121448  3.700000e-01
# 121449  1.387400e+02
# 121450  5.397605e-79
# 121451  2.606000e+01
# 121452  3.900000e-01
# 121453  6.100000e-01
# 121454  6.017000e+01
# 121456  1.320000e+01
# 121457  2.598000e+01
# 121458  5.276000e+01
# 121459  5.397605e-79
# ...

# %%
data
# Out:
#            SEQN        WTDRD1        WTDR2D  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 0       83732.0  92670.699919  6.994593e+04       1.0       1.0      71.0
# 1       83732.0  92670.699919  6.994593e+04       2.0       1.0      71.0
# 2       83732.0  92670.699919  6.994593e+04       3.0       1.0      71.0
# 3       83732.0  92670.699919  6.994593e+04       4.0       1.0      71.0
# 4       83732.0  92670.699919  6.994593e+04       5.0       1.0      71.0
# 5       83732.0  92670.699919  6.994593e+04       6.0       1.0      71.0
# 6       83732.0  92670.699919  6.994593e+04       7.0       1.0      71.0
# 7       83732.0  92670.699919  6.994593e+04       8.0       1.0      71.0
# 8       83732.0  92670.699919  6.994593e+04       9.0       1.0      71.0
# 9       83732.0  92670.699919  6.994593e+04      10.0       1.0      71.0
# 10      83732.0  92670.699919  6.994593e+04      11.0       1.0      71.0
# 11      83732.0  92670.699919  6.994593e+04      12.0       1.0      71.0
# ...

# %%
newdata = data[['SEQN', 'DR1ILINE', 'DR1_020', 'DR1_030Z', 'DR1ICARB']].copy()

# %%
newdata
# Out:
#            SEQN  DR1ILINE  DR1_020  DR1_030Z      DR1ICARB
# 0       83732.0       1.0  27000.0       1.0  5.397605e-79
# 1       83732.0       2.0  27000.0       1.0  3.560000e+00
# 2       83732.0       3.0  27000.0       1.0  2.320000e+00
# 3       83732.0       4.0  28800.0       7.0  5.397605e-79
# 4       83732.0       5.0  32400.0       1.0  4.088000e+01
# 5       83732.0       6.0  32400.0       1.0  2.500000e-01
# 6       83732.0       7.0  41400.0       6.0  1.740000e+00
# 7       83732.0       8.0  45000.0       2.0  4.867000e+01
# 8       83732.0       9.0  45000.0       2.0  1.170000e+00
# 9       83732.0      10.0  45000.0       2.0  2.740000e+00
# 10      83732.0      11.0  45000.0       2.0  5.397605e-79
# 11      83732.0      12.0  64800.0       4.0  1.330000e+00
# 12      83732.0      13.0  64800.0       4.0  8.460000e+00
# 13      83732.0      14.0  64800.0       4.0  5.397605e-79
# 14      83732.0      15.0  64800.0       4.0  5.961000e+01
# ...

# %%
time = []
cho = []
for a, b in newdata.iterrows():
    if b['SEQN'] == 83732.0:
        time.append(b['DR1_020'])
        cho.append(b['DR1ICARB'])

# %%
print(time)
print(cho)
# Out:
# [27000.0, 27000.0, 27000.0, 28800.0, 32400.0, 32400.0, 41400.0, 45000.0, 45000.0, 45000.0, 45000.0, 64800.0, 64800.0, 64800.0, 64800.0, 75600.0]
# [5.397605346934028e-79, 3.56, 2.32, 5.397605346934028e-79, 40.88, 0.25, 1.74, 48.67, 1.17, 2.74, 5.397605346934028e-79, 1.33, 8.46, 5.397605346934028e-79, 59.61, 22.56]

# %%
plt.plot(time, cho)

# %%
Xnew = data[['DR1_020']].copy()

# %%
Y
# Out:
#             DR1ICARB
# 0       5.397605e-79
# 1       3.560000e+00
# 2       2.320000e+00
# 3       5.397605e-79
# 4       4.088000e+01
# 5       2.500000e-01
# 6       1.740000e+00
# 7       4.867000e+01
# 8       1.170000e+00
# 9       2.740000e+00
# 10      5.397605e-79
# 11      1.330000e+00
# 12      8.460000e+00
# 13      5.397605e-79
# 14      5.961000e+01
# 16      2.256000e+01
# 17      5.397605e-79
# 18      8.330000e+00
# 19      4.723000e+01
# 20      1.047000e+01
# 21      2.821000e+01
# 22      2.549000e+02
# 23      5.397605e-79
# 24      7.710000e+00
# 25      7.200000e-01
# 26      9.900000e-01
# 27      5.397605e-79
# 28      6.970000e+00
# 29      2.612000e+01
# 30      1.600000e-01
# ...              ...
# 121448  3.700000e-01
# 121449  1.387400e+02
# 121450  5.397605e-79
# 121451  2.606000e+01
# 121452  3.900000e-01
# 121453  6.100000e-01
# 121454  6.017000e+01
# 121456  1.320000e+01
# 121457  2.598000e+01
# 121458  5.276000e+01
# 121459  5.397605e-79
# ...

# %%
X_train_new, X_test_new, y_train, y_test = train_test_split(Xnew, Y, random_state=0)

# %%
y_test
# Out:
#             DR1ICARB
# 18313   1.199100e+02
# 95025   2.400000e-01
# 94499   1.634000e+01
# 24936   7.700000e-01
# 110842  3.220000e+00
# 95129   4.646000e+01
# 61240   1.127000e+01
# 25679   6.800000e-01
# 113226  2.287000e+01
# 91550   4.490000e+00
# 72898   1.000000e-02
# 91727   6.490000e+01
# 24748   2.119000e+01
# 761     1.245000e+01
# 49690   6.107000e+01
# 96400   3.257000e+01
# 69511   5.640000e+00
# 27616   2.564000e+01
# 37891   5.120000e+00
# 41200   1.360000e+00
# 13550   1.250000e+00
# 57783   3.587000e+01
# 69689   8.350000e+00
# 30243   2.090000e+00
# 31960   2.200000e-01
# 50583   4.131000e+01
# 25086   5.510000e+00
# 27133   7.700000e-01
# 29920   5.430000e+00
# 43982   6.730000e+00
# ...              ...
# 56869   3.750000e+00
# 59090   4.619000e+01
# 22107   2.131000e+01
# 99207   1.816000e+01
# 88633   3.651000e+01
# 61267   1.385000e+01
# 114631  1.318000e+01
# 70528   1.750000e+00
# 57608   5.995000e+01
# 56290   8.700000e-01
# 26811   4.600000e-01
# ...

# %%
lrnew = LinearRegression().fit(X_train_new,y_train)

# %%
lrnew.score(X_train_new, y_train)
# Out:
# 0.0026908236597953383

# %%
lrnew.score(X_test_new, y_test)
# Out:
# 0.0045750514821564225

# %%
print(time)
print(cho)
# Out:
# [27000.0, 27000.0, 27000.0, 28800.0, 32400.0, 32400.0, 41400.0, 45000.0, 45000.0, 45000.0, 45000.0, 64800.0, 64800.0, 64800.0, 64800.0, 75600.0]
# [5.397605346934028e-79, 3.56, 2.32, 5.397605346934028e-79, 40.88, 0.25, 1.74, 48.67, 1.17, 2.74, 5.397605346934028e-79, 1.33, 8.46, 5.397605346934028e-79, 59.61, 22.56]

# %%
plt.plot(time, cho)

# %%
people = newdata.SEQN.unique()

# %%
len(people)
# Out:
# 8258

# %%
for p in people:
    time = []
    cho = []
    for a, b in newdata.iterrows():
        if b['SEQN'] == p:
            time.append(b['DR1_020'])
            cho.append(b['DR1ICARB'])
            plt.plot(time, cho)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-8454998bb95e> in <module>
#       3     cho = []
#       4     for a, b in newdata.iterrows():
# ----> 5         if b['SEQN'] == p:
#       6             time.append(b['DR1_020'])
#       7             cho.append(b['DR1ICARB'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     763
#     764     def __getitem__(self, key):
# --> 765         key = com._apply_if_callable(key, self)
#     766         try:
#     767             result = self.index.get_value(self, key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in _apply_if_callable(maybe_callable, obj, **kwargs)
#     405     """
#     406
# --> 407     if callable(maybe_callable):
#     408         return maybe_callable(obj, **kwargs)
#     409
#
# KeyboardInterrupt:
