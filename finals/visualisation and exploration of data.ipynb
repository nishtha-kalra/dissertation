# %%
import numpy as np
import pandas as pd
data = pd.read_sas('DR1IFF_I.xpt')

# %% [markdown]
# ### Relation between CHO and days of week

# %%
data = data.dropna()
X = data[['SEQN', 'DR1_020', 'DR1DAY', 'DR1ICARB']].copy()

# %%
X
# Out:
#            SEQN  DR1_020  DR1DAY      DR1ICARB
# 0       83732.0  27000.0     1.0  5.397605e-79
# 1       83732.0  27000.0     1.0  3.560000e+00
# 2       83732.0  27000.0     1.0  2.320000e+00
# 3       83732.0  28800.0     1.0  5.397605e-79
# 4       83732.0  32400.0     1.0  4.088000e+01
# 5       83732.0  32400.0     1.0  2.500000e-01
# 6       83732.0  41400.0     1.0  1.740000e+00
# 7       83732.0  45000.0     1.0  4.867000e+01
# 8       83732.0  45000.0     1.0  1.170000e+00
# 9       83732.0  45000.0     1.0  2.740000e+00
# 10      83732.0  45000.0     1.0  5.397605e-79
# 11      83732.0  64800.0     1.0  1.330000e+00
# 12      83732.0  64800.0     1.0  8.460000e+00
# 13      83732.0  64800.0     1.0  5.397605e-79
# 14      83732.0  64800.0     1.0  5.961000e+01
# 16      83732.0  75600.0     1.0  2.256000e+01
# 17      83733.0  37800.0     7.0  5.397605e-79
# 18      83733.0  37800.0     7.0  8.330000e+00
# 19      83733.0  46800.0     7.0  4.723000e+01
# 20      83733.0  72000.0     7.0  1.047000e+01
# 21      83733.0  72000.0     7.0  2.821000e+01
# 22      83733.0  72000.0     7.0  2.549000e+02
# 23      83733.0  72000.0     7.0  5.397605e-79
# 24      83733.0  72000.0     7.0  7.710000e+00
# 25      83734.0  32400.0     7.0  7.200000e-01
# 26      83734.0  32400.0     7.0  9.900000e-01
# 27      83734.0  32400.0     7.0  5.397605e-79
# 28      83734.0  32400.0     7.0  6.970000e+00
# 29      83734.0  32400.0     7.0  2.612000e+01
# 30      83734.0  32400.0     7.0  1.600000e-01
# ...         ...      ...     ...           ...
# 121448  93699.0  67500.0     7.0  3.700000e-01
# 121449  93699.0  67500.0     7.0  1.387400e+02
# 121450  93699.0  67500.0     7.0  5.397605e-79
# 121451  93701.0  31200.0     7.0  2.606000e+01
# 121452  93701.0  31200.0     7.0  3.900000e-01
# 121453  93701.0  31200.0     7.0  6.100000e-01
# 121454  93701.0  31200.0     7.0  6.017000e+01
# 121456  93701.0  42600.0     7.0  1.320000e+01
# 121457  93701.0  42600.0     7.0  2.598000e+01
# 121458  93701.0  42600.0     7.0  5.276000e+01
# 121459  93701.0  42600.0     7.0  5.397605e-79
# 121460  93701.0  42600.0     7.0  9.480000e+00
# 121461  93701.0  51300.0     7.0  1.347000e+01
# 121462  93701.0  52200.0     7.0  2.626000e+01
# 121463  93701.0  57600.0     7.0  2.192000e+01
# 121464  93701.0  68400.0     7.0  2.094000e+01
# 121465  93701.0  68400.0     7.0  1.671000e+01
# 121466  93701.0  68400.0     7.0  3.493000e+01
# 121469  93702.0  32400.0     7.0  5.397605e-79
# 121470  93702.0  39600.0     7.0  1.832000e+01
# 121471  93702.0  50400.0     7.0  5.397605e-79
# 121472  93702.0  50400.0     7.0  1.230000e+00
# 121473  93702.0  55800.0     7.0  1.190000e+00
# 121474  93702.0  55800.0     7.0  1.690000e+00
# 121475  93702.0  55800.0     7.0  1.300000e-01
# 121476  93702.0  55800.0     7.0  5.480000e+00
# 121477  93702.0  55800.0     7.0  3.036000e+01
# 121478  93702.0  73800.0     7.0  7.830000e+00
# 121479  93702.0  73800.0     7.0  2.640000e+00
# 121480  93702.0  73800.0     7.0  1.170000e+00
#
# [110191 rows x 4 columns]

# %%
sun = 0
mon = 0
tue = 0
wed = 0
thu = 0
fri = 0
sat = 0
sunc = 0
monc = 0
tuec = 0
wedc = 0
thuc = 0
fric = 0
satc = 0

# %%
for row, value in X.iterrows():
    if value['DR1DAY'] == 1.0:
        sunc += 1
        sun = sun + value['DR1ICARB']
    if value['DR1DAY'] == 2.0:
        monc += 1
        mon = mon + value['DR1ICARB']
    if value['DR1DAY'] == 3.0:
        tuec += 1
        tue = tue + value['DR1ICARB']
    if value['DR1DAY'] == 4.0:
        wedc += 1
        wed = wed + value['DR1ICARB']
    if value['DR1DAY'] == 5.0:
        thuc += 1
        thu = thu + value['DR1ICARB']
    if value['DR1DAY'] == 6.0:
        fric += 1
        fri = fri + value['DR1ICARB']
    if value['DR1DAY'] == 7.0:
        satc += 1
        sat = sat + value['DR1ICARB']

# %%
print(sun)
print(mon)
print(tue)
print(wed)
print(thu)
print(fri)
print(sat)
print(sunc)
print(monc)
print(tuec)
print(wedc)
print(thuc)
print(fric)
print(satc)
# Out:
# 327727.14999999886
# 129051.96999999939
# 172814.81999999983
# 158047.15999999963
# 141812.64999999997
# 537023.5700000022
# 474046.93999999866
# 18526
# 7763
# 10458
# 9269
# 8704
# 30476
# 24995

# %%
week1 = ['sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat']
week = [sun/sunc, mon/monc, tue/tuec, wed/wedc, thu/thuc, fri/fric, sat/satc]

# %%
import matplotlib.pyplot as plt
plt.bar(np.arange(len(week1)), week)
plt.xticks(np.arange(len(week1)), week1)
plt.ylabel('average CHO level')
# Out:
# Text(0, 0.5, 'average CHO level')

# %% [markdown]
# People generally take high CHO diet on Sunday, Friday and Saturday.

# %% [markdown]
# ### Relation between CHO and Language respondent used mostly

# %%
lang = data[['SEQN', 'DR1_020', 'DR1LANG', 'DR1ICARB']].copy()

# %%
lang
# Out:
#            SEQN  DR1_020  DR1LANG      DR1ICARB
# 0       83732.0  27000.0      1.0  5.397605e-79
# 1       83732.0  27000.0      1.0  3.560000e+00
# 2       83732.0  27000.0      1.0  2.320000e+00
# 3       83732.0  28800.0      1.0  5.397605e-79
# 4       83732.0  32400.0      1.0  4.088000e+01
# 5       83732.0  32400.0      1.0  2.500000e-01
# 6       83732.0  41400.0      1.0  1.740000e+00
# 7       83732.0  45000.0      1.0  4.867000e+01
# 8       83732.0  45000.0      1.0  1.170000e+00
# 9       83732.0  45000.0      1.0  2.740000e+00
# 10      83732.0  45000.0      1.0  5.397605e-79
# 11      83732.0  64800.0      1.0  1.330000e+00
# 12      83732.0  64800.0      1.0  8.460000e+00
# 13      83732.0  64800.0      1.0  5.397605e-79
# 14      83732.0  64800.0      1.0  5.961000e+01
# 16      83732.0  75600.0      1.0  2.256000e+01
# 17      83733.0  37800.0      1.0  5.397605e-79
# 18      83733.0  37800.0      1.0  8.330000e+00
# 19      83733.0  46800.0      1.0  4.723000e+01
# 20      83733.0  72000.0      1.0  1.047000e+01
# 21      83733.0  72000.0      1.0  2.821000e+01
# 22      83733.0  72000.0      1.0  2.549000e+02
# 23      83733.0  72000.0      1.0  5.397605e-79
# 24      83733.0  72000.0      1.0  7.710000e+00
# 25      83734.0  32400.0      1.0  7.200000e-01
# 26      83734.0  32400.0      1.0  9.900000e-01
# 27      83734.0  32400.0      1.0  5.397605e-79
# 28      83734.0  32400.0      1.0  6.970000e+00
# 29      83734.0  32400.0      1.0  2.612000e+01
# 30      83734.0  32400.0      1.0  1.600000e-01
# ...         ...      ...      ...           ...
# 121448  93699.0  67500.0      1.0  3.700000e-01
# 121449  93699.0  67500.0      1.0  1.387400e+02
# 121450  93699.0  67500.0      1.0  5.397605e-79
# 121451  93701.0  31200.0      1.0  2.606000e+01
# 121452  93701.0  31200.0      1.0  3.900000e-01
# 121453  93701.0  31200.0      1.0  6.100000e-01
# 121454  93701.0  31200.0      1.0  6.017000e+01
# 121456  93701.0  42600.0      1.0  1.320000e+01
# 121457  93701.0  42600.0      1.0  2.598000e+01
# 121458  93701.0  42600.0      1.0  5.276000e+01
# 121459  93701.0  42600.0      1.0  5.397605e-79
# 121460  93701.0  42600.0      1.0  9.480000e+00
# 121461  93701.0  51300.0      1.0  1.347000e+01
# 121462  93701.0  52200.0      1.0  2.626000e+01
# 121463  93701.0  57600.0      1.0  2.192000e+01
# 121464  93701.0  68400.0      1.0  2.094000e+01
# 121465  93701.0  68400.0      1.0  1.671000e+01
# 121466  93701.0  68400.0      1.0  3.493000e+01
# 121469  93702.0  32400.0      1.0  5.397605e-79
# 121470  93702.0  39600.0      1.0  1.832000e+01
# 121471  93702.0  50400.0      1.0  5.397605e-79
# 121472  93702.0  50400.0      1.0  1.230000e+00
# 121473  93702.0  55800.0      1.0  1.190000e+00
# 121474  93702.0  55800.0      1.0  1.690000e+00
# 121475  93702.0  55800.0      1.0  1.300000e-01
# 121476  93702.0  55800.0      1.0  5.480000e+00
# 121477  93702.0  55800.0      1.0  3.036000e+01
# 121478  93702.0  73800.0      1.0  7.830000e+00
# 121479  93702.0  73800.0      1.0  2.640000e+00
# 121480  93702.0  73800.0      1.0  1.170000e+00
#
# [110191 rows x 4 columns]

# %%
English = 0
Spanish = 0
EnglishandSpanish = 0
Other = 0
Asian = 0
AsianandEnglish = 0
Englishc = 0
Spanishc = 0
EnglishandSpanishc = 0
Otherc = 0
Asianc = 0
AsianandEnglishc = 0

# %%
for row, value in lang.iterrows():
    if value['DR1LANG'] == 1.0:
        Englishc += 1
        English = English + value['DR1ICARB']
    if value['DR1LANG'] == 2.0:
        Spanishc += 1
        Spanish = Spanish + value['DR1ICARB']
    if value['DR1LANG'] == 3.0:
        EnglishandSpanishc += 1
        EnglishandSpanish = EnglishandSpanish + value['DR1ICARB']
    if value['DR1LANG'] == 4.0:
        Otherc += 1
        Other = Other + value['DR1ICARB']
    if value['DR1LANG'] == 5.0:
        Asianc += 1
        Asian = Asian + value['DR1ICARB']
    if value['DR1LANG'] == 6.0:
        AsianandEnglishc += 1
        AsianandEnglish = AsianandEnglish + value['DR1ICARB']

# %%
print(English) 
print(Spanish) 
print(EnglishandSpanish) 
print(Other) 
print(Asian) 
print(AsianandEnglish)
print(Englishc) 
print(Spanishc) 
print(EnglishandSpanishc) 
print(Otherc) 
print(Asianc) 
print(AsianandEnglishc)
# Out:
# 1668128.59000008
# 227378.09999999974
# 18409.31
# 9920.82000000001
# 9373.35
# 7314.089999999998
# 94725
# 12739
# 1027
# 576
# 651
# 473

# %%
94725+12739+1027+576+651+473
# Out:
# 110191

# %%
langc = ['English', 'Spanish', 'English\n and Spanish', 'Other', 'Asian', 'Asian\n and English']
lang = [English/Englishc, Spanish/Spanishc, EnglishandSpanish/EnglishandSpanishc, Other/Otherc, Asian/Asianc, AsianandEnglish/AsianandEnglishc]

# %%
lang
# Out:
# [17.610225283716865,
#  17.848975586780732,
#  17.92532619279455,
#  17.22364583333335,
#  14.398387096774194,
#  15.46319238900634]

# %%
plt.bar(np.arange(len(langc)), lang)
plt.xticks(np.arange(len(langc)), langc)
plt.ylabel('average CHO level')
# Out:
# Text(0, 0.5, 'average CHO level')

# %% [markdown]
# People speaking English and Spanish consume most Carbohydrates while people sepaking Asian languages consume least Carbohydrates

# %% [markdown]
# ### Relation between CHO level and Combination food type

# %%
food = data[['SEQN', 'DR1_020', 'DR1CCMTX', 'DR1ICARB']].copy()

# %%
food
# Out:
#            SEQN  DR1_020      DR1CCMTX      DR1ICARB
# 0       83732.0  27000.0  1.000000e+00  5.397605e-79
# 1       83732.0  27000.0  1.000000e+00  3.560000e+00
# 2       83732.0  27000.0  1.000000e+00  2.320000e+00
# 3       83732.0  28800.0  5.397605e-79  5.397605e-79
# 4       83732.0  32400.0  3.000000e+00  4.088000e+01
# 5       83732.0  32400.0  3.000000e+00  2.500000e-01
# 6       83732.0  41400.0  5.397605e-79  1.740000e+00
# 7       83732.0  45000.0  5.000000e+00  4.867000e+01
# 8       83732.0  45000.0  5.000000e+00  1.170000e+00
# 9       83732.0  45000.0  5.000000e+00  2.740000e+00
# 10      83732.0  45000.0  5.397605e-79  5.397605e-79
# 11      83732.0  64800.0  5.397605e-79  1.330000e+00
# 12      83732.0  64800.0  5.397605e-79  8.460000e+00
# 13      83732.0  64800.0  5.397605e-79  5.397605e-79
# 14      83732.0  64800.0  5.397605e-79  5.961000e+01
# 16      83732.0  75600.0  5.397605e-79  2.256000e+01
# 17      83733.0  37800.0  1.000000e+00  5.397605e-79
# 18      83733.0  37800.0  1.000000e+00  8.330000e+00
# 19      83733.0  46800.0  5.397605e-79  4.723000e+01
# 20      83733.0  72000.0  5.397605e-79  1.047000e+01
# 21      83733.0  72000.0  5.397605e-79  2.821000e+01
# 22      83733.0  72000.0  5.397605e-79  2.549000e+02
# 23      83733.0  72000.0  5.397605e-79  5.397605e-79
# 24      83733.0  72000.0  5.397605e-79  7.710000e+00
# 25      83734.0  32400.0  5.397605e-79  7.200000e-01
# 26      83734.0  32400.0  5.397605e-79  9.900000e-01
# 27      83734.0  32400.0  1.000000e+00  5.397605e-79
# 28      83734.0  32400.0  1.000000e+00  6.970000e+00
# 29      83734.0  32400.0  3.000000e+00  2.612000e+01
# 30      83734.0  32400.0  3.000000e+00  1.600000e-01
# ...         ...      ...           ...           ...
# 121448  93699.0  67500.0  4.000000e+00  3.700000e-01
# 121449  93699.0  67500.0  5.397605e-79  1.387400e+02
# 121450  93699.0  67500.0  5.397605e-79  5.397605e-79
# 121451  93701.0  31200.0  5.000000e+00  2.606000e+01
# 121452  93701.0  31200.0  5.000000e+00  3.900000e-01
# 121453  93701.0  31200.0  5.000000e+00  6.100000e-01
# 121454  93701.0  31200.0  5.397605e-79  6.017000e+01
# 121456  93701.0  42600.0  5.397605e-79  1.320000e+01
# 121457  93701.0  42600.0  5.397605e-79  2.598000e+01
# 121458  93701.0  42600.0  5.397605e-79  5.276000e+01
# 121459  93701.0  42600.0  5.397605e-79  5.397605e-79
# 121460  93701.0  42600.0  5.397605e-79  9.480000e+00
# 121461  93701.0  51300.0  5.397605e-79  1.347000e+01
# 121462  93701.0  52200.0  5.397605e-79  2.626000e+01
# 121463  93701.0  57600.0  5.397605e-79  2.192000e+01
# 121464  93701.0  68400.0  5.397605e-79  2.094000e+01
# 121465  93701.0  68400.0  5.397605e-79  1.671000e+01
# 121466  93701.0  68400.0  5.397605e-79  3.493000e+01
# 121469  93702.0  32400.0  5.397605e-79  5.397605e-79
# 121470  93702.0  39600.0  5.397605e-79  1.832000e+01
# 121471  93702.0  50400.0  5.397605e-79  5.397605e-79
# 121472  93702.0  50400.0  5.397605e-79  1.230000e+00
# 121473  93702.0  55800.0  4.000000e+00  1.190000e+00
# 121474  93702.0  55800.0  4.000000e+00  1.690000e+00
# 121475  93702.0  55800.0  4.000000e+00  1.300000e-01
# 121476  93702.0  55800.0  4.000000e+00  5.480000e+00
# 121477  93702.0  55800.0  4.000000e+00  3.036000e+01
# 121478  93702.0  73800.0  5.397605e-79  7.830000e+00
# 121479  93702.0  73800.0  9.000000e+01  2.640000e+00
# 121480  93702.0  73800.0  9.000000e+01  1.170000e+00
#
# [110191 rows x 4 columns]

# %%
fooddict = {
    1 : { 'name' : 'beverage', 'count' : 0, 'cho' : 0},
    2 : { 'name' : 'cereal', 'count' : 0, 'cho' : 0},
    3 : { 'name' : 'bread', 'count' : 0, 'cho' : 0},
    4 : { 'name' : 'salad', 'count' : 0, 'cho' : 0},
    5 : { 'name' : 'sandwich', 'count' : 0, 'cho' : 0}, 
    6 : { 'name' : 'soup', 'count' : 0, 'cho' : 0},
    7 : { 'name' : 'frozen', 'count' : 0, 'cho' : 0},
    8 : { 'name' : 'icecream', 'count' : 0, 'cho' : 0},
    9 : { 'name' : 'driedbean', 'count' : 0, 'cho' : 0},
    10 : { 'name' : 'fruit', 'count' : 0, 'cho' : 0},
    11 : { 'name' : 'tortilla', 'count' : 0, 'cho' : 0},
    12 : { 'name' : 'meat', 'count' : 0, 'cho' : 0},
    13 : { 'name' : 'luncables', 'count' : 0, 'cho' : 0},
    14 : { 'name' : 'chips', 'count' : 0, 'cho' : 0}
}

# %%
fooddict
# Out:
# {1: {'name': 'beverage', 'count': 0, 'cho': 0},
#  2: {'name': 'cereal', 'count': 0, 'cho': 0},
#  3: {'name': 'bread', 'count': 0, 'cho': 0},
#  4: {'name': 'salad', 'count': 0, 'cho': 0},
#  5: {'name': 'sandwich', 'count': 0, 'cho': 0},
#  6: {'name': 'soup', 'count': 0, 'cho': 0},
#  7: {'name': 'frozen', 'count': 0, 'cho': 0},
#  8: {'name': 'icecream', 'count': 0, 'cho': 0},
#  9: {'name': 'driedbean', 'count': 0, 'cho': 0},
#  10: {'name': 'fruit', 'count': 0, 'cho': 0},
#  11: {'name': 'tortilla', 'count': 0, 'cho': 0},
#  12: {'name': 'meat', 'count': 0, 'cho': 0},
#  13: {'name': 'luncables', 'count': 0, 'cho': 0},
#  14: {'name': 'chips', 'count': 0, 'cho': 0}}

# %%
for key in fooddict.keys():
    for row, value in food.iterrows():
        if value['DR1CCMTX'] == key:
            fooddict[key]['count'] += 1
            fooddict[key]['cho'] += value['DR1ICARB']

# %%
fooddict
# Out:
# {1: {'name': 'beverage', 'count': 9288, 'cho': 60651.52000000052},
#  2: {'name': 'cereal', 'count': 4737, 'cho': 99956.62999999977},
#  3: {'name': 'bread', 'count': 4861, 'cho': 85405.6299999997},
#  4: {'name': 'salad', 'count': 4404, 'cho': 13292.850000000044},
#  5: {'name': 'sandwich', 'count': 8255, 'cho': 82064.06999999903},
#  6: {'name': 'soup', 'count': 666, 'cho': 9579.630000000006},
#  7: {'name': 'frozen', 'count': 41, 'cho': 733.3299999999997},
#  8: {'name': 'icecream', 'count': 434, 'cho': 9788.469999999992},
#  9: {'name': 'driedbean', 'count': 3114, 'cho': 33542.99000000005},
#  10: {'name': 'fruit', 'count': 677, 'cho': 6009.139999999996},
#  11: {'name': 'tortilla', 'count': 1907, 'cho': 44681.98999999999},
#  12: {'name': 'meat', 'count': 2578, 'cho': 18337.030000000024},
#  13: {'name': 'luncables', 'count': 171, 'cho': 1146.5299999999997},
#  14: {'name': 'chips', 'count': 690, 'cho': 9966.299999999988}}

# %%
foodnames = []
foodcho = []
for key in fooddict:
    foodnames.append(fooddict[key]['name'])
    foodcho.append(fooddict[key]['cho']/fooddict[key]['count'])
print(foodnames)
print(foodcho)
# Out:
# ['beverage', 'cereal', 'bread', 'salad', 'sandwich', 'soup', 'frozen', 'icecream', 'driedbean', 'fruit', 'tortilla', 'meat', 'luncables', 'chips']
# [6.530094745908755, 21.1012518471606, 17.569559761365912, 3.018358310626713, 9.941135069654637, 14.383828828828838, 17.886097560975603, 22.554078341013806, 10.77167308927426, 8.876129985228944, 23.430513896171995, 7.11288983708302, 6.704853801169589, 14.443913043478243]

# %%
plt.bar(np.arange(len(foodnames)), foodcho)
plt.xticks(np.arange(len(foodnames)), foodnames)
plt.ylabel('average CHO level')
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# ### Relation of CHO with DR2_030Z - Name of eating occasion

# %%
occasion = data[['DR1_030Z', 'DR1ICARB']].copy()

# %%
occasion
# Out:
#         DR1_030Z      DR1ICARB
# 0            1.0  5.397605e-79
# 1            1.0  3.560000e+00
# 2            1.0  2.320000e+00
# 3            7.0  5.397605e-79
# 4            1.0  4.088000e+01
# 5            1.0  2.500000e-01
# 6            6.0  1.740000e+00
# 7            2.0  4.867000e+01
# 8            2.0  1.170000e+00
# 9            2.0  2.740000e+00
# 10           2.0  5.397605e-79
# 11           4.0  1.330000e+00
# 12           4.0  8.460000e+00
# 13           4.0  5.397605e-79
# 14           4.0  5.961000e+01
# 16           6.0  2.256000e+01
# 17           3.0  5.397605e-79
# 18           3.0  8.330000e+00
# 19           9.0  4.723000e+01
# 20           3.0  1.047000e+01
# 21           3.0  2.821000e+01
# 22           3.0  2.549000e+02
# 23           3.0  5.397605e-79
# 24           3.0  7.710000e+00
# 25           1.0  7.200000e-01
# 26           1.0  9.900000e-01
# 27           1.0  5.397605e-79
# 28           1.0  6.970000e+00
# 29           1.0  2.612000e+01
# 30           1.0  1.600000e-01
# ...          ...           ...
# 121448       3.0  3.700000e-01
# 121449       3.0  1.387400e+02
# 121450       3.0  5.397605e-79
# 121451       1.0  2.606000e+01
# 121452       1.0  3.900000e-01
# 121453       1.0  6.100000e-01
# 121454       1.0  6.017000e+01
# 121456       2.0  1.320000e+01
# 121457       2.0  2.598000e+01
# 121458       2.0  5.276000e+01
# 121459       2.0  5.397605e-79
# 121460       2.0  9.480000e+00
# 121461       6.0  1.347000e+01
# 121462       6.0  2.626000e+01
# 121463       6.0  2.192000e+01
# 121464       3.0  2.094000e+01
# 121465       3.0  1.671000e+01
# 121466       3.0  3.493000e+01
# 121469       7.0  5.397605e-79
# 121470       1.0  1.832000e+01
# 121471       9.0  5.397605e-79
# 121472       6.0  1.230000e+00
# 121473       2.0  1.190000e+00
# 121474       2.0  1.690000e+00
# 121475       2.0  1.300000e-01
# 121476       2.0  5.480000e+00
# 121477       2.0  3.036000e+01
# 121478       3.0  7.830000e+00
# 121479       3.0  2.640000e+00
# 121480       3.0  1.170000e+00
#
# [110191 rows x 2 columns]

# %%
occasiondict = {
    1 : { 'name' : 'Breakfast\nDesayano', 'count' : 0, 'cho' : 0},
    2 : { 'name' : 'Lunch\nAlmuerzo\nCena', 'count' : 0, 'cho' : 0},
    3 : { 'name' : 'Dinner', 'count' : 0, 'cho' : 0},
    4 : { 'name' : 'Supper', 'count' : 0, 'cho' : 0},
    5 : { 'name' : 'Brunch', 'count' : 0, 'cho' : 0},
    6 : { 'name' : 'Snack\nMerienda\nBotana\nBocadillo\nTentempie', 'count' : 0, 'cho' : 0},
    7 : { 'name' : 'Drink\nBebida', 'count' : 0, 'cho' : 0},
    8 : { 'name' : 'Infant feeding', 'count' : 0, 'cho' : 0},
    9 : { 'name' : 'Extended consumption\nEntre comida', 'count' : 0, 'cho' : 0},
    12 : { 'name' : 'Comida', 'count' : 0, 'cho' : 0}
}

# %%
occasiondict
# Out:
# {1: {'name': 'Breakfast\nDesayano', 'count': 0, 'cho': 0},
#  2: {'name': 'Lunch\nAlmuerzo\nCena', 'count': 0, 'cho': 0},
#  3: {'name': 'Dinner', 'count': 0, 'cho': 0},
#  4: {'name': 'Supper', 'count': 0, 'cho': 0},
#  5: {'name': 'Brunch', 'count': 0, 'cho': 0},
#  6: {'name': 'Snack\nMerienda\nBotana\nBocadillo\nTentempie',
#   'count': 0,
#   'cho': 0},
#  7: {'name': 'Drink\nBebida', 'count': 0, 'cho': 0},
#  8: {'name': 'Infant feeding', 'count': 0, 'cho': 0},
#  9: {'name': 'Extended consumption\nEntre comida', 'count': 0, 'cho': 0},
#  12: {'name': 'Comida', 'count': 0, 'cho': 0}}

# %% [markdown]
# Merging keys of spanish words with english words

# %%
for row, value in occasion.iterrows():
    if value['DR1_030Z'] == 10:
        value['DR1_030Z'] = 1
    elif value['DR1_030Z'] == 11 or value['DR1_030Z'] == 14:
        value['DR1_030Z'] = 2
    elif value['DR1_030Z'] == 13 or value['DR1_030Z'] == 16 or value['DR1_030Z'] == 17 or value['DR1_030Z'] == 18:
        value['DR1_030Z'] = 6
    elif value['DR1_030Z'] == 19:
        value['DR1_030Z'] = 7
    elif value['DR1_030Z'] == 15:
        value['DR1_030Z'] = 9

# %% [markdown]
# Calculating count and carbohydrate level of each eating occasion

# %%
for key in occasiondict.keys():
    for row, value in occasion.iterrows():
        if value['DR1_030Z'] == key:
            occasiondict[key]['count'] += 1
            occasiondict[key]['cho'] += value['DR1ICARB']

# %%
occasiondict
# Out:
# {1: {'name': 'Breakfast\nDesayano', 'count': 22975, 'cho': 364918.97000000195},
#  2: {'name': 'Lunch\nAlmuerzo\nCena',
#   'count': 26475,
#   'cho': 480816.2400000028},
#  3: {'name': 'Dinner', 'count': 22485, 'cho': 425710.6700000021},
#  4: {'name': 'Supper', 'count': 5529, 'cho': 103013.59999999995},
#  5: {'name': 'Brunch', 'count': 1014, 'cho': 16873.380000000012},
#  6: {'name': 'Snack\nMerienda\nBotana\nBocadillo\nTentempie',
#   'count': 20048,
#   'cho': 382567.5400000013},
#  7: {'name': 'Drink\nBebida', 'count': 5015, 'cho': 60326.75000000013},
#  8: {'name': 'Infant feeding', 'count': 2176, 'cho': 20506.00999999997},
#  9: {'name': 'Extended consumption\nEntre comida',
#   'count': 2365,
#   'cho': 43668.100000000035},
#  12: {'name': 'Comida', 'count': 2109, 'cho': 42123.00000000007}}

# %% [markdown]
# Creating list of names of occasion of food and average CHO level of each food ocassion

# %%
occasionnames = []
occasioncho = []
for key in occasiondict: 
    occasionnames.append(occasiondict[key]['name'])
    occasioncho.append(occasiondict[key]['cho']/occasiondict[key]['count'])
print(occasionnames)
print(occasioncho)
# Out:
# ['Breakfast\nDesayano', 'Lunch\nAlmuerzo\nCena', 'Dinner', 'Supper', 'Brunch', 'Snack\nMerienda\nBotana\nBocadillo\nTentempie', 'Drink\nBebida', 'Infant feeding', 'Extended consumption\nEntre comida', 'Comida']
# [15.883306637649705, 18.161142209631834, 18.933096286413257, 18.631506601555426, 16.640414201183443, 19.082578810854017, 12.029262213359946, 9.423717830882339, 18.464312896405936, 19.972972972973007]

# %%
plt.bar(np.arange(len(occasionnames)), occasioncho)
plt.xticks(np.arange(len(occasionnames)), occasionnames)
plt.ylabel('average CHO level')
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# Relation between CHO levels and DR2_040Z - Did you eat this meal at home?

# %%
athome = data[['DR1_040Z', 'DR1ICARB']].copy()

# %%
athome
# Out:
#         DR1_040Z      DR1ICARB
# 0            1.0  5.397605e-79
# 1            1.0  3.560000e+00
# 2            1.0  2.320000e+00
# 3            1.0  5.397605e-79
# 4            1.0  4.088000e+01
# 5            1.0  2.500000e-01
# 6            2.0  1.740000e+00
# 7            1.0  4.867000e+01
# 8            1.0  1.170000e+00
# 9            1.0  2.740000e+00
# 10           1.0  5.397605e-79
# 11           1.0  1.330000e+00
# 12           1.0  8.460000e+00
# 13           1.0  5.397605e-79
# 14           1.0  5.961000e+01
# 16           1.0  2.256000e+01
# 17           1.0  5.397605e-79
# 18           1.0  8.330000e+00
# 19           1.0  4.723000e+01
# 20           1.0  1.047000e+01
# 21           1.0  2.821000e+01
# 22           1.0  2.549000e+02
# 23           1.0  5.397605e-79
# 24           1.0  7.710000e+00
# 25           1.0  7.200000e-01
# 26           1.0  9.900000e-01
# 27           1.0  5.397605e-79
# 28           1.0  6.970000e+00
# 29           1.0  2.612000e+01
# 30           1.0  1.600000e-01
# ...          ...           ...
# 121448       1.0  3.700000e-01
# 121449       1.0  1.387400e+02
# 121450       1.0  5.397605e-79
# 121451       2.0  2.606000e+01
# 121452       2.0  3.900000e-01
# 121453       2.0  6.100000e-01
# 121454       2.0  6.017000e+01
# 121456       1.0  1.320000e+01
# 121457       1.0  2.598000e+01
# 121458       1.0  5.276000e+01
# 121459       1.0  5.397605e-79
# 121460       1.0  9.480000e+00
# 121461       2.0  1.347000e+01
# 121462       1.0  2.626000e+01
# 121463       1.0  2.192000e+01
# 121464       1.0  2.094000e+01
# 121465       1.0  1.671000e+01
# 121466       1.0  3.493000e+01
# 121469       1.0  5.397605e-79
# 121470       1.0  1.832000e+01
# 121471       2.0  5.397605e-79
# 121472       2.0  1.230000e+00
# 121473       2.0  1.190000e+00
# 121474       2.0  1.690000e+00
# 121475       2.0  1.300000e-01
# 121476       2.0  5.480000e+00
# 121477       2.0  3.036000e+01
# 121478       2.0  7.830000e+00
# 121479       2.0  2.640000e+00
# 121480       2.0  1.170000e+00
#
# [110191 rows x 2 columns]

# %%
yes = 0
no = 0
yesc = 0
noc = 0
for row, value in athome.iterrows():
    if value['DR1_040Z'] == 1.0:
        yesc += 1
        yes = yes + value['DR1ICARB']
    if value['DR1_040Z'] == 2.0:
        noc += 1
        no = no + value['DR1ICARB']

# %%
print(yes/yesc)
print(no/noc)
# Out:
# 17.293894069132378
# 18.319328535761446

# %%
print (yes)
print(yesc)
print(no)
print(noc)
# Out:
# 1316826.2700000159
# 76144
# 623681.5399999984
# 34045

# %%
plt.bar([0,1], [yes/yesc,no/noc])
plt.xticks(np.arange(2), ['at home', 'not at home'])
fig_size[0] = 5
plt.ylabel("Average CHO levels")
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# Food not cosumed at home has more carbohydrates
