# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import timedelta

# %%
data2 = pd.read_sas('DR2IFF_I.XPT')

# %%
data2 = data2.dropna()

# %%
data2
# Out:
#            SEQN        WTDRD1        WTDR2D  DR2ILINE  DR2DRSTZ  DR2EXMER  \
# 0       83732.0  92670.699919  69945.934107       1.0       1.0      87.0
# 1       83732.0  92670.699919  69945.934107       2.0       1.0      87.0
# 2       83732.0  92670.699919  69945.934107       3.0       1.0      87.0
# 4       83732.0  92670.699919  69945.934107       5.0       1.0      87.0
# 5       83732.0  92670.699919  69945.934107       6.0       1.0      87.0
# 6       83732.0  92670.699919  69945.934107       7.0       1.0      87.0
# 7       83732.0  92670.699919  69945.934107       8.0       1.0      87.0
# 8       83732.0  92670.699919  69945.934107       9.0       1.0      87.0
# 9       83732.0  92670.699919  69945.934107      10.0       1.0      87.0
# 10      83732.0  92670.699919  69945.934107      12.0       1.0      87.0
# 11      83732.0  92670.699919  69945.934107      13.0       1.0      87.0
# 12      83732.0  92670.699919  69945.934107      14.0       1.0      87.0
# ...

# %%
data1 = pd.read_csv('meal.csv')
data1 = data1.dropna()

# %%
# removing this for now as linear regression can't be applied on datetime format
#df['DR1_020'] = pd.to_datetime(df['DR1_020'], unit='s').dt.time

# %%
data2[0:23]
# Out:
#        SEQN        WTDRD1        WTDR2D  DR2ILINE  DR2DRSTZ  DR2EXMER  DRABF  \
# 0   83732.0  92670.699919  69945.934107       1.0       1.0      87.0    2.0
# 1   83732.0  92670.699919  69945.934107       2.0       1.0      87.0    2.0
# 2   83732.0  92670.699919  69945.934107       3.0       1.0      87.0    2.0
# 4   83732.0  92670.699919  69945.934107       5.0       1.0      87.0    2.0
# 5   83732.0  92670.699919  69945.934107       6.0       1.0      87.0    2.0
# 6   83732.0  92670.699919  69945.934107       7.0       1.0      87.0    2.0
# 7   83732.0  92670.699919  69945.934107       8.0       1.0      87.0    2.0
# 8   83732.0  92670.699919  69945.934107       9.0       1.0      87.0    2.0
# 9   83732.0  92670.699919  69945.934107      10.0       1.0      87.0    2.0
# 10  83732.0  92670.699919  69945.934107      12.0       1.0      87.0    2.0
# 11  83732.0  92670.699919  69945.934107      13.0       1.0      87.0    2.0
# ...

# %%
oneparticipant1 = data1[0:16][['DR1_020', 'DR1ICARB']].copy()
oneparticipant2 = data2[0:23][['DR2_020', 'DR2ICARB']].copy()
#oneparticipant1 = data1[['DR1_020', 'DR1ICARB']].copy()
#oneparticipant2 = data2[['DR2_020', 'DR2ICARB']].copy()

# %%
oneparticipant2.columns = ['time', 'CHO']
oneparticipant1.columns = ['time', 'CHO']

# %%
oneparticipant = pd.concat([oneparticipant1, oneparticipant2])
oneparticipant
# Out:
#        time           CHO
# 0   27000.0  5.397605e-79
# 1   27000.0  3.560000e+00
# 2   27000.0  2.320000e+00
# 3   28800.0  5.397605e-79
# 4   32400.0  4.088000e+01
# 5   32400.0  2.500000e-01
# 6   41400.0  1.740000e+00
# 7   45000.0  4.867000e+01
# 8   45000.0  1.170000e+00
# 9   45000.0  2.740000e+00
# 10  45000.0  5.397605e-79
# 11  64800.0  1.330000e+00
# 12  64800.0  8.460000e+00
# 13  64800.0  5.397605e-79
# 14  64800.0  5.961000e+01
# 16  75600.0  2.256000e+01
# 0   18000.0  5.397605e-79
# 1   18000.0  1.780000e+00
# 2   18000.0  1.160000e+00
# 4   26100.0  3.823000e+01
# 5   26100.0  2.342000e+01
# 6   26100.0  4.614000e+01
# 7   37800.0  5.397605e-79
# 8   37800.0  1.717000e+01
# 9   45900.0  6.940000e+00
# 10  45900.0  3.430000e+00
# 11  45900.0  2.465000e+01
# 12  45900.0  2.964000e+01
# 13  54900.0  5.397605e-79
# 14  54900.0  2.591000e+01
# 15  66600.0  5.397605e-79
# 16  66600.0  2.606000e+01
# 17  66600.0  2.400000e-01
# 18  66600.0  1.170000e+00
# ...

# %%
oneparticipant = oneparticipant.sort_values(by=['time'])

# %%
#oneparticipant['time'] = pd.to_datetime(oneparticipant['time'], unit='s').dt.time
#oneparticipant['time'] = pd.to_datetime(oneparticipant['time'], unit='s')

# %%
oneparticipant.size
# Out:
# 78

# %%
#oneparticipant.head()
type(oneparticipant.iloc[0]['time'])
# Out:
# numpy.float64

# %%
plt.plot(oneparticipant['time'], oneparticipant['CHO'])

# %%
plt.scatter(oneparticipant['time'], oneparticipant['CHO'])

# %%
#oneparticipant.head()
import datetime as dt
print(type(oneparticipant['time'][0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
first_row = pd.DataFrame({'time': 0,
                        'CHO': 0}, index =[0]) 
oneparticipant = pd.concat([first_row, oneparticipant]).reset_index(drop = True) 
oneparticipant
# Out:
#        time           CHO
# 0       0.0  0.000000e+00
# 1   18000.0  1.160000e+00
# 2   18000.0  1.780000e+00
# 3   18000.0  5.397605e-79
# 4   26100.0  3.823000e+01
# 5   26100.0  4.614000e+01
# 6   26100.0  2.342000e+01
# 7   27000.0  5.397605e-79
# 8   27000.0  3.560000e+00
# 9   27000.0  2.320000e+00
# 10  28800.0  5.397605e-79
# 11  32400.0  4.088000e+01
# 12  32400.0  2.500000e-01
# 13  37800.0  5.397605e-79
# 14  37800.0  1.717000e+01
# 15  41400.0  1.740000e+00
# 16  45000.0  4.867000e+01
# 17  45000.0  5.397605e-79
# 18  45000.0  2.740000e+00
# 19  45000.0  1.170000e+00
# 20  45900.0  2.964000e+01
# 21  45900.0  2.465000e+01
# 22  45900.0  3.430000e+00
# 23  45900.0  6.940000e+00
# 24  54900.0  2.591000e+01
# 25  54900.0  5.397605e-79
# 26  64800.0  5.961000e+01
# 27  64800.0  8.460000e+00
# 28  64800.0  5.397605e-79
# 29  64800.0  1.330000e+00
# 30  66600.0  5.397605e-79
# 31  66600.0  5.397605e-79
# 32  66600.0  2.606000e+01
# 33  66600.0  2.400000e-01
# ...

# %%
oneparticipant = oneparticipant.append({'time': 0,
                                        'CHO': 0} , ignore_index=True)

# %%
oneparticipant.tail()
# Out:
#        time    CHO
# 36  66600.0   0.29
# 37  66600.0   0.48
# 38  75600.0  22.56
# 39  75600.0  34.85
# 40      0.0   0.00

# %%
X = oneparticipant[0:(len(oneparticipant)-1)]
X
# Out:
#        time           CHO
# 0       0.0  0.000000e+00
# 1   18000.0  1.160000e+00
# 2   18000.0  1.780000e+00
# 3   18000.0  5.397605e-79
# 4   26100.0  3.823000e+01
# 5   26100.0  4.614000e+01
# 6   26100.0  2.342000e+01
# 7   27000.0  5.397605e-79
# 8   27000.0  3.560000e+00
# 9   27000.0  2.320000e+00
# 10  28800.0  5.397605e-79
# 11  32400.0  4.088000e+01
# 12  32400.0  2.500000e-01
# 13  37800.0  5.397605e-79
# 14  37800.0  1.717000e+01
# 15  41400.0  1.740000e+00
# 16  45000.0  4.867000e+01
# 17  45000.0  5.397605e-79
# 18  45000.0  2.740000e+00
# 19  45000.0  1.170000e+00
# 20  45900.0  2.964000e+01
# 21  45900.0  2.465000e+01
# 22  45900.0  3.430000e+00
# 23  45900.0  6.940000e+00
# 24  54900.0  2.591000e+01
# 25  54900.0  5.397605e-79
# 26  64800.0  5.961000e+01
# 27  64800.0  8.460000e+00
# 28  64800.0  5.397605e-79
# 29  64800.0  1.330000e+00
# 30  66600.0  5.397605e-79
# 31  66600.0  5.397605e-79
# 32  66600.0  2.606000e+01
# 33  66600.0  2.400000e-01
# ...

# %%
print(type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
y = oneparticipant[1:(len(oneparticipant))]
y
# Out:
#        time           CHO
# 1   18000.0  1.160000e+00
# 2   18000.0  1.780000e+00
# 3   18000.0  5.397605e-79
# 4   26100.0  3.823000e+01
# 5   26100.0  4.614000e+01
# 6   26100.0  2.342000e+01
# 7   27000.0  5.397605e-79
# 8   27000.0  3.560000e+00
# 9   27000.0  2.320000e+00
# 10  28800.0  5.397605e-79
# 11  32400.0  4.088000e+01
# 12  32400.0  2.500000e-01
# 13  37800.0  5.397605e-79
# 14  37800.0  1.717000e+01
# 15  41400.0  1.740000e+00
# 16  45000.0  4.867000e+01
# 17  45000.0  5.397605e-79
# 18  45000.0  2.740000e+00
# 19  45000.0  1.170000e+00
# 20  45900.0  2.964000e+01
# 21  45900.0  2.465000e+01
# 22  45900.0  3.430000e+00
# 23  45900.0  6.940000e+00
# 24  54900.0  2.591000e+01
# 25  54900.0  5.397605e-79
# 26  64800.0  5.961000e+01
# 27  64800.0  8.460000e+00
# 28  64800.0  5.397605e-79
# 29  64800.0  1.330000e+00
# 30  66600.0  5.397605e-79
# 31  66600.0  5.397605e-79
# 32  66600.0  2.606000e+01
# 33  66600.0  2.400000e-01
# 34  66600.0  1.170000e+00
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
X_test
# Out:
#        time           CHO
# 22  45900.0  3.430000e+00
# 20  45900.0  2.964000e+01
# 25  54900.0  5.397605e-79
# 4   26100.0  3.823000e+01
# 10  28800.0  5.397605e-79
# 15  41400.0  1.740000e+00
# 28  64800.0  5.397605e-79
# 11  32400.0  4.088000e+01
# 18  45000.0  2.740000e+00
# 29  64800.0  1.330000e+00

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train,y_train)
#print(lr.score(X_train, y_train)*100)

# %%
print(lr.score(X_train, y_train))
# Out:
# 0.5897665817009704

# %%
print(lr.score(X_test, y_test))
# Out:
# 0.9111442287659517

# %%
from sklearn.linear_model import Ridge
rd = Ridge().fit(X_train,y_train)
print(rd.score(X_train, y_train)*100)
print(rd.score(X_test, y_test)*100)
# Out:
# 58.976658124361826
# 91.1145912961209

# %%
'''
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
'''
# Out:
# '\nfrom keras.models import Sequential\nfrom keras.layers import Dense\nfrom keras.layers import LSTM\n'

# %%
'''
model = Sequential()
model.add(Dense(12, input_dim=2, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2, activation='sigmoid'))
'''
# Out:
# "\nmodel = Sequential()\nmodel.add(Dense(12, input_dim=2, activation='relu'))\nmodel.add(Dense(8, activation='relu'))\nmodel.add(Dense(2, activation='sigmoid'))\n"

# %%
'''
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=10, batch_size=10)
'''
# Out:
# "\nmodel.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])\nmodel.fit(X, y, epochs=10, batch_size=10)\n"

# %%
'''
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
'''
# Out:
# "\n_, accuracy = model.evaluate(X, y)\nprint('Accuracy: %.2f' % (accuracy*100))\n"

# %%
'''
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
model = AR(X[0:len(X),0])
model_fit = model.fit(maxlag=6, disp=False)
window = model_fit.k_ar
coef = model_fit.params
'''
# Out:
# '\nfrom statsmodels.tsa.ar_model import AR\nfrom sklearn.metrics import mean_squared_error\nmodel = AR(X[0:len(X),0])\nmodel_fit = model.fit(maxlag=6, disp=False)\nwindow = model_fit.k_ar\ncoef = model_fit.params\n'

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# %%
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# %%
X.shape
# Out:
# (40, 2)

# %%
y.shape
# Out:
# (40, 2)

# %%
gp.fit(X_train, y_train)
# Out:
# /home/nishtha/anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.10533076e+09, -3.13102226e+06]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 72, 'nit': 4, 'warnflag': 2}
#   ConvergenceWarning)
# /home/nishtha/anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-4.68368293e+08, -3.32561873e+07]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 78, 'nit': 3, 'warnflag': 2}
#   ConvergenceWarning)
# /home/nishtha/anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:480: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([1.03795036e+09, 3.44374033e+06]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 138, 'nit': 23, 'warnflag': 2}
#   ConvergenceWarning)
# ...

# %%
print(gp.score(X_train,y_train))
print(gp.score(X_test, y_test))
# Out:
# 0.999999972576821
# -11.625351493793062
